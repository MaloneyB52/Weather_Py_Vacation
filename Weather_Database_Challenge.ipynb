# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data.
# ---
# 1. Generate a new set of 2000 random latitudes and longitudes.
# 2. Get the nearest city.
# 3. Perform an API call with the OpenWeatherMap.
# 4. Retrieve the following information from the API call.
#     - The latitude and longitude
#     - The maximum temperature
#     - The % humidity
#     - The % cloudiness
#     - The Wind speed
#     - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.
# 5. Add the data to a new DataFrame.
# 6. Save the new DataFrame as a CSV file.

# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 746

# %%
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ### Retrieve the following information from the API call.
#     - The latitude and longitude
#     - The Max temperature
#     - The % humidity
#     - The % cloudiness
#     - The Wind speed
#     - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
import json
import pprint

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)
    city_weather = requests.get(city_url).json()
    print(city_weather)
#     print(json.dumps(city_weather, indent=4, sort_keys=True))
#     pprint.pprint(city_weather)
#     break
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
#         city_weather = requests.get(city_url).json()
#         print(json.dumps(city_weather, indent=4, sort_keys=True))
#         print(city_weather)
#         break
        
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=attawapiskat
# {'cod': '404', 'message': 'city not found'}
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=jamestown
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 24.55, 'feels_like': 15.1, 'temp_min': 23.34, 'temp_max': 27.72, 'pressure': 988, 'humidity': 70}, 'visibility': 2816, 'wind': {'speed': 8.99, 'deg': 318, 'gust': 14}, 'snow': {'1h': 0.75}, 'clouds': {'all': 100}, 'dt': 1642432619, 'sys': {'type': 2, 'id': 2008828, 'country': 'US', 'sunrise': 1642423299, 'sunset': 1642457522}, 'timezone': -18000, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# Processing Record 2 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=mogadishu
# {'coord': {'lon': 45.3438, 'lat': 2.0371}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 79.23, 'feels_like': 79.23, 'temp_min': 79.23, 'temp_max': 79.23, 'pressure': 1010, 'humidity': 76, 'sea_level': 1010, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 21, 'deg': 82, 'gust': 27.07}, 'clouds': {'all': 32}, 'dt': 1642432706, 'sys': {'country': 'SO', 'sunrise': 1642388877, 'sunset': 1642432132}, 'timezone': 10800, 'id': 53654, 'name': 'Mogadishu', 'cod': 200}
# Processing Record 3 of Set 1 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=hermanus
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 83.8, 'feels_like': 88.84, 'temp_min': 76.89, 'temp_max': 83.8, 'pressure': 1010, 'humidity': 66, 'sea_level': 1010, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 13.6, 'deg': 176, 'gust': 17.78}, 'clouds': {'all': 11}, 'dt': 1642432793, 'sys': {'type': 2, 'id': 2006131, 'country': 'ZA', 'sunrise': 1642391291, 'sunset': 1642442254}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Processing Record 4 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=mar+del+plata
# {'coord': {'lon': -57.5575, 'lat': -38.0023}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 65.88, 'feels_like': 64.74, 'temp_min': 65.88, 'temp_max': 69.01, 'pressure': 1015, 'humidity': 55, 'sea_level': 1015, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 18.99, 'deg': 146, 'gust': 28.01}, 'rain': {'1h': 1.91}, 'clouds': {'all': 100}, 'dt': 1642432735, 'sys': {'type': 2, 'id': 2000296, 'country': 'AR', 'sunrise': 1642409197, 'sunset': 1642461216}, 'timezone': -10800, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}
# Processing Record 5 of Set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=tambul
# {'cod': '404', 'message': 'city not found'}
# Processing Record 6 of Set 1 | tambul
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=udachnyy
# {'coord': {'lon': 112.4, 'lat': 66.4167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -7.83, 'feels_like': -20.43, 'temp_min': -7.83, 'temp_max': -7.83, 'pressure': 1028, 'humidity': 97, 'sea_level': 1028, 'grnd_level': 988}, 'visibility': 398, 'wind': {'speed': 12.93, 'deg': 182, 'gust': 27.69}, 'clouds': {'all': 100}, 'dt': 1642432794, 'sys': {'country': 'RU', 'sunrise': 1642472519, 'sunset': 1642489136}, 'timezone': 32400, 'id': 2014624, 'name': 'Udachny', 'cod': 200}
# Processing Record 7 of Set 1 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=saint+george
# {'coord': {'lon': -113.5841, 'lat': 37.1041}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 30.79, 'feels_like': 30.79, 'temp_min': 30.79, 'temp_max': 32.47, 'pressure': 1021, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 0}, 'dt': 1642432716, 'sys': {'type': 1, 'id': 5832, 'country': 'US', 'sunrise': 1642430762, 'sunset': 1642466551}, 'timezone': -25200, 'id': 5546220, 'name': 'Saint George', 'cod': 200}
# Processing Record 8 of Set 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=esperance
# {'coord': {'lon': 121.9, 'lat': -33.8667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 61.09, 'feels_like': 60.37, 'temp_min': 61.09, 'temp_max': 61.09, 'pressure': 1019, 'humidity': 74, 'sea_level': 1019, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 17.4, 'deg': 74, 'gust': 26.87}, 'clouds': {'all': 4}, 'dt': 1642432795, 'sys': {'country': 'AU', 'sunrise': 1642366713, 'sunset': 1642417541}, 'timezone': 28800, 'id': 2071860, 'name': 'Esperance', 'cod': 200}
# Processing Record 9 of Set 1 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=khatanga
# {'coord': {'lon': 102.5, 'lat': 71.9667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': -18.09, 'feels_like': -30.69, 'temp_min': -18.09, 'temp_max': -18.09, 'pressure': 1012, 'humidity': 94, 'sea_level': 1012, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 7.87, 'deg': 93, 'gust': 12.5}, 'clouds': {'all': 10}, 'dt': 1642432795, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 2022572, 'name': 'Khatanga', 'cod': 200}
# Processing Record 10 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=taolanaro
# {'cod': '404', 'message': 'city not found'}
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=thompson
# {'coord': {'lon': -97.8558, 'lat': 55.7435}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': -27.24, 'feels_like': -39.84, 'temp_min': -27.24, 'temp_max': -27.24, 'pressure': 1014, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 300}, 'clouds': {'all': 20}, 'dt': 1642432796, 'sys': {'type': 1, 'id': 935, 'country': 'CA', 'sunrise': 1642430917, 'sunset': 1642458844}, 'timezone': -21600, 'id': 6165406, 'name': 'Thompson', 'cod': 200}
# Processing Record 12 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=ribeira+grande
# {'coord': {'lon': -28.7, 'lat': 38.5167}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 59.4, 'feels_like': 58.42, 'temp_min': 59.4, 'temp_max': 59.4, 'pressure': 1015, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 110}, 'clouds': {'all': 40}, 'dt': 1642432796, 'sys': {'type': 1, 'id': 6883, 'country': 'PT', 'sunrise': 1642410603, 'sunset': 1642445955}, 'timezone': -3600, 'id': 3372707, 'name': 'Ribeira Grande', 'cod': 200}
# Processing Record 13 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=kholuy
# {'coord': {'lon': 41.8692, 'lat': 56.575}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 24.6, 'feels_like': 13.71, 'temp_min': 24.6, 'temp_max': 24.6, 'pressure': 988, 'humidity': 95, 'sea_level': 988, 'grnd_level': 978}, 'visibility': 176, 'wind': {'speed': 11.54, 'deg': 198, 'gust': 28.25}, 'snow': {'1h': 0.36}, 'clouds': {'all': 100}, 'dt': 1642432796, 'sys': {'country': 'RU', 'sunrise': 1642397691, 'sunset': 1642424987}, 'timezone': 10800, 'id': 549645, 'name': 'Kholuy', 'cod': 200}
# Processing Record 14 of Set 1 | kholuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=araouane
# {'coord': {'lon': -3.5265, 'lat': 18.9048}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 78.4, 'feels_like': 76.37, 'temp_min': 78.4, 'temp_max': 78.4, 'pressure': 1018, 'humidity': 9, 'sea_level': 1018, 'grnd_level': 986}, 'visibility': 10000, 'wind': {'speed': 15.21, 'deg': 75, 'gust': 16.6}, 'clouds': {'all': 3}, 'dt': 1642432797, 'sys': {'country': 'ML', 'sunrise': 1642402199, 'sunset': 1642442274}, 'timezone': 0, 'id': 2460954, 'name': 'Araouane', 'cod': 200}
# Processing Record 15 of Set 1 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=karratha
# {'coord': {'lon': 116.8463, 'lat': -20.7377}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 81.73, 'feels_like': 86.36, 'temp_min': 81.73, 'temp_max': 81.73, 'pressure': 1005, 'humidity': 72, 'sea_level': 1005, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 12.62, 'deg': 277, 'gust': 13.09}, 'clouds': {'all': 37}, 'dt': 1642432797, 'sys': {'country': 'AU', 'sunrise': 1642369523, 'sunset': 1642417157}, 'timezone': 28800, 'id': 6620339, 'name': 'Karratha', 'cod': 200}
# Processing Record 16 of Set 1 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=bluff
# {'coord': {'lon': 168.3333, 'lat': -46.6}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 58.8, 'feels_like': 58.48, 'temp_min': 58.8, 'temp_max': 58.8, 'pressure': 1012, 'humidity': 87, 'sea_level': 1012, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 3.96, 'deg': 79, 'gust': 4.41}, 'clouds': {'all': 13}, 'dt': 1642432798, 'sys': {'type': 2, 'id': 2008959, 'country': 'NZ', 'sunrise': 1642439826, 'sunset': 1642494975}, 'timezone': 46800, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# Processing Record 17 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=vostok
# {'coord': {'lon': 135.8833, 'lat': 46.4856}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -5.62, 'feels_like': -5.62, 'temp_min': -5.62, 'temp_max': -5.62, 'pressure': 1020, 'humidity': 100, 'sea_level': 1020, 'grnd_level': 942}, 'visibility': 1377, 'wind': {'speed': 1.83, 'deg': 302, 'gust': 2.77}, 'clouds': {'all': 100}, 'dt': 1642432798, 'sys': {'country': 'RU', 'sunrise': 1642458861, 'sunset': 1642491520}, 'timezone': 36000, 'id': 2013279, 'name': 'Vostok', 'cod': 200}
# Processing Record 18 of Set 1 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=nome
# {'coord': {'lon': -165.4064, 'lat': 64.5011}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -0.35, 'feels_like': -12.95, 'temp_min': -10.84, 'temp_max': -0.33, 'pressure': 1020, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 350}, 'clouds': {'all': 100}, 'dt': 1642432798, 'sys': {'type': 1, 'id': 7770, 'country': 'US', 'sunrise': 1642451254, 'sunset': 1642470939}, 'timezone': -32400, 'id': 5870133, 'name': 'Nome', 'cod': 200}
# Processing Record 19 of Set 1 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=podgorica
# {'coord': {'lon': 19.2636, 'lat': 42.4411}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 48.18, 'feels_like': 48.18, 'temp_min': 47.98, 'temp_max': 51.51, 'pressure': 1021, 'humidity': 49}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 0}, 'dt': 1642432799, 'sys': {'type': 1, 'id': 7035, 'country': 'ME', 'sunrise': 1642399727, 'sunset': 1642433804}, 'timezone': 3600, 'id': 3193044, 'name': 'Podgorica', 'cod': 200}
# Processing Record 20 of Set 1 | podgorica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=castro
# {'coord': {'lon': -50.0119, 'lat': -24.7911}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75, 'feels_like': 75.58, 'temp_min': 75, 'temp_max': 75, 'pressure': 1015, 'humidity': 72, 'sea_level': 1015, 'grnd_level': 906}, 'visibility': 10000, 'wind': {'speed': 9.33, 'deg': 251, 'gust': 11.77}, 'clouds': {'all': 82}, 'dt': 1642432799, 'sys': {'country': 'BR', 'sunrise': 1642409142, 'sunset': 1642457649}, 'timezone': -10800, 'id': 3466704, 'name': 'Castro', 'cod': 200}
# Processing Record 21 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=punta+arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 48.22, 'feels_like': 40.51, 'temp_min': 48.11, 'temp_max': 48.31, 'pressure': 1019, 'humidity': 53}, 'visibility': 10000, 'wind': {'speed': 24.16, 'deg': 260}, 'clouds': {'all': 75}, 'dt': 1642432799, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1642409127, 'sunset': 1642467701}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 22 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=kutum
# {'coord': {'lon': 24.6667, 'lat': 14.2}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 73.62, 'feels_like': 71.53, 'temp_min': 73.62, 'temp_max': 73.62, 'pressure': 1013, 'humidity': 18, 'sea_level': 1013, 'grnd_level': 888}, 'visibility': 10000, 'wind': {'speed': 10.74, 'deg': 54, 'gust': 8.01}, 'clouds': {'all': 3}, 'dt': 1642432800, 'sys': {'country': 'SD', 'sunrise': 1642394969, 'sunset': 1642435968}, 'timezone': 7200, 'id': 371745, 'name': 'Kutum', 'cod': 200}
# Processing Record 23 of Set 1 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=portland
# {'coord': {'lon': -122.6762, 'lat': 45.5234}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 37.36, 'feels_like': 37.36, 'temp_min': 34.38, 'temp_max': 40.21, 'pressure': 1019, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 223, 'gust': 4}, 'clouds': {'all': 75}, 'dt': 1642432615, 'sys': {'type': 2, 'id': 2008548, 'country': 'US', 'sunrise': 1642434338, 'sunset': 1642467340}, 'timezone': -28800, 'id': 5746545, 'name': 'Portland', 'cod': 200}
# Processing Record 24 of Set 1 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=dolbeau
# {'cod': '404', 'message': 'city not found'}
# Processing Record 25 of Set 1 | dolbeau
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=galgani
# {'cod': '404', 'message': 'city not found'}
# Processing Record 26 of Set 1 | galgani
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=puerto+ayora
# {'coord': {'lon': -90.3518, 'lat': -0.7393}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.16, 'feels_like': 76.1, 'temp_min': 75.16, 'temp_max': 75.16, 'pressure': 1015, 'humidity': 79, 'sea_level': 1015, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 6.13, 'deg': 152, 'gust': 8.9}, 'clouds': {'all': 80}, 'dt': 1642432801, 'sys': {'type': 1, 'id': 8521, 'country': 'EC', 'sunrise': 1642421199, 'sunset': 1642464959}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# Processing Record 27 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=bengkulu
# {'coord': {'lon': 102.2655, 'lat': -3.8004}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 77.59, 'feels_like': 79.2, 'temp_min': 77.59, 'temp_max': 77.59, 'pressure': 1012, 'humidity': 88, 'sea_level': 1012, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 3.98, 'deg': 28, 'gust': 4.88}, 'rain': {'1h': 0.75}, 'clouds': {'all': 100}, 'dt': 1642432802, 'sys': {'country': 'ID', 'sunrise': 1642374680, 'sunset': 1642419001}, 'timezone': 25200, 'id': 1649150, 'name': 'Bengkulu', 'cod': 200}
# Processing Record 28 of Set 1 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=pasni
# {'coord': {'lon': 63.471, 'lat': 25.2631}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 71.76, 'feels_like': 71.28, 'temp_min': 71.76, 'temp_max': 71.76, 'pressure': 1020, 'humidity': 56, 'sea_level': 1020, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 5.01, 'deg': 136, 'gust': 5.17}, 'clouds': {'all': 0}, 'dt': 1642432802, 'sys': {'country': 'PK', 'sunrise': 1642386791, 'sunset': 1642425516}, 'timezone': 18000, 'id': 1168312, 'name': 'Pasni', 'cod': 200}
# Processing Record 29 of Set 1 | pasni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=sawang+daen+din
# {'coord': {'lon': 103.4575, 'lat': 17.4753}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 74.17, 'feels_like': 74.59, 'temp_min': 74.17, 'temp_max': 79.07, 'pressure': 1016, 'humidity': 70, 'sea_level': 1016, 'grnd_level': 996}, 'visibility': 10000, 'wind': {'speed': 14.12, 'deg': 117, 'gust': 27.87}, 'clouds': {'all': 4}, 'dt': 1642432803, 'sys': {'type': 2, 'id': 2034401, 'country': 'TH', 'sunrise': 1642376378, 'sunset': 1642416730}, 'timezone': 25200, 'id': 1606350, 'name': 'Sawang Daen Din', 'cod': 200}
# Processing Record 30 of Set 1 | sawang daen din
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=anadyr
# {'coord': {'lon': 177.4833, 'lat': 64.75}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': -29, 'feels_like': -41.6, 'temp_min': -29, 'temp_max': -28.7, 'pressure': 1033, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 6.71, 'deg': 360}, 'clouds': {'all': 0}, 'dt': 1642432803, 'sys': {'type': 2, 'id': 47746, 'country': 'RU', 'sunrise': 1642455534, 'sunset': 1642474874}, 'timezone': 43200, 'id': 2127202, 'name': 'Anadyr', 'cod': 200}
# Processing Record 31 of Set 1 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=san+cristobal
# {'coord': {'lon': -72.225, 'lat': 7.7669}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.38, 'feels_like': 75.2, 'temp_min': 75.38, 'temp_max': 75.38, 'pressure': 1016, 'humidity': 55, 'sea_level': 1016, 'grnd_level': 917}, 'visibility': 10000, 'wind': {'speed': 5.77, 'deg': 133, 'gust': 9.35}, 'clouds': {'all': 100}, 'dt': 1642432803, 'sys': {'type': 1, 'id': 8587, 'country': 'VE', 'sunrise': 1642417622, 'sunset': 1642459834}, 'timezone': -14400, 'id': 3628473, 'name': 'San Cristobal', 'cod': 200}
# Processing Record 32 of Set 1 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=south+yarmouth
# {'coord': {'lon': -70.1847, 'lat': 41.6668}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}, {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 48.94, 'feels_like': 46.96, 'temp_min': 45, 'temp_max': 51.98, 'pressure': 986, 'humidity': 94}, 'visibility': 8047, 'wind': {'speed': 5.01, 'deg': 146, 'gust': 10}, 'rain': {'1h': 0.56}, 'clouds': {'all': 100}, 'dt': 1642432804, 'sys': {'type': 2, 'id': 2011360, 'country': 'US', 'sunrise': 1642421056, 'sunset': 1642455421}, 'timezone': -18000, 'id': 4951579, 'name': 'South Yarmouth', 'cod': 200}
# Processing Record 33 of Set 1 | south yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=sao+filipe
# {'coord': {'lon': -24.4956, 'lat': 14.8961}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 72.84, 'feels_like': 73.2, 'temp_min': 72.84, 'temp_max': 72.84, 'pressure': 1016, 'humidity': 72, 'sea_level': 1016, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 8.5, 'deg': 352, 'gust': 9.46}, 'clouds': {'all': 0}, 'dt': 1642432804, 'sys': {'country': 'CV', 'sunrise': 1642406836, 'sunset': 1642447704}, 'timezone': -3600, 'id': 3374210, 'name': 'São Filipe', 'cod': 200}
# Processing Record 34 of Set 1 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=narsaq
# {'coord': {'lon': -46.05, 'lat': 60.9167}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 28.62, 'feels_like': 21.49, 'temp_min': 28.62, 'temp_max': 28.62, 'pressure': 996, 'humidity': 95, 'sea_level': 996, 'grnd_level': 993}, 'visibility': 915, 'wind': {'speed': 6.91, 'deg': 98, 'gust': 9.98}, 'snow': {'1h': 0.35}, 'clouds': {'all': 100}, 'dt': 1642432805, 'sys': {'type': 1, 'id': 47, 'country': 'GL', 'sunrise': 1642420545, 'sunset': 1642444343}, 'timezone': -10800, 'id': 3421719, 'name': 'Narsaq', 'cod': 200}
# Processing Record 35 of Set 1 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=vao
# {'coord': {'lon': 167.4833, 'lat': -22.6667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 76.35, 'feels_like': 76.69, 'temp_min': 76.35, 'temp_max': 76.35, 'pressure': 1009, 'humidity': 64, 'sea_level': 1009, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 14.76, 'deg': 109, 'gust': 14.5}, 'clouds': {'all': 62}, 'dt': 1642432805, 'sys': {'country': 'NC', 'sunrise': 1642443598, 'sunset': 1642491611}, 'timezone': 39600, 'id': 2137773, 'name': 'Vao', 'cod': 200}
# Processing Record 36 of Set 1 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=saskylakh
# {'coord': {'lon': 114.0833, 'lat': 71.9167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -15.03, 'feels_like': -27.63, 'temp_min': -15.03, 'temp_max': -15.03, 'pressure': 1020, 'humidity': 94, 'sea_level': 1020, 'grnd_level': 1019}, 'visibility': 4806, 'wind': {'speed': 13.76, 'deg': 155, 'gust': 27.51}, 'clouds': {'all': 96}, 'dt': 1642432805, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 32400, 'id': 2017155, 'name': 'Saskylakh', 'cod': 200}
# Processing Record 37 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=butaritari
# {'coord': {'lon': 172.7902, 'lat': 3.0707}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 82.06, 'feels_like': 88.18, 'temp_min': 82.06, 'temp_max': 82.06, 'pressure': 1006, 'humidity': 77, 'sea_level': 1006, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 15.88, 'deg': 68, 'gust': 17.31}, 'clouds': {'all': 54}, 'dt': 1642432806, 'sys': {'country': 'KI', 'sunrise': 1642444795, 'sunset': 1642487866}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# Processing Record 38 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 44.26, 'feels_like': 34.63, 'temp_min': 44.26, 'temp_max': 46.02, 'pressure': 1016, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 27.63, 'deg': 230}, 'clouds': {'all': 75}, 'dt': 1642432723, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1642407964, 'sunset': 1642467607}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# Processing Record 39 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=hobart
# {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 56.8, 'feels_like': 55.38, 'temp_min': 54.27, 'temp_max': 57.25, 'pressure': 1009, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 290}, 'clouds': {'all': 50}, 'dt': 1642432760, 'sys': {'type': 2, 'id': 2002195, 'country': 'AU', 'sunrise': 1642445619, 'sunset': 1642499266}, 'timezone': 39600, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# Processing Record 40 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=nantucket
# {'coord': {'lon': -70.0995, 'lat': 41.2835}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 49.5, 'feels_like': 43.25, 'temp_min': 46.74, 'temp_max': 51.94, 'pressure': 988, 'humidity': 90}, 'visibility': 2816, 'wind': {'speed': 18.41, 'deg': 190}, 'clouds': {'all': 100}, 'dt': 1642432806, 'sys': {'type': 1, 'id': 3218, 'country': 'US', 'sunrise': 1642420972, 'sunset': 1642455464}, 'timezone': -18000, 'id': 4944903, 'name': 'Nantucket', 'cod': 200}
# Processing Record 41 of Set 1 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=dikson
# {'coord': {'lon': 80.5464, 'lat': 73.5069}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 9.64, 'feels_like': -2.79, 'temp_min': 9.64, 'temp_max': 9.64, 'pressure': 999, 'humidity': 88, 'sea_level': 999, 'grnd_level': 993}, 'visibility': 10000, 'wind': {'speed': 8.48, 'deg': 111, 'gust': 14.58}, 'clouds': {'all': 100}, 'dt': 1642432807, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# Processing Record 42 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=mataura
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 58.48, 'feels_like': 58.3, 'temp_min': 58.48, 'temp_max': 58.48, 'pressure': 1012, 'humidity': 91, 'sea_level': 1012, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 1.28, 'deg': 323, 'gust': 1.5}, 'clouds': {'all': 2}, 'dt': 1642432807, 'sys': {'type': 2, 'id': 2008959, 'country': 'NZ', 'sunrise': 1642439786, 'sunset': 1642494760}, 'timezone': 46800, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# Processing Record 43 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=hithadhoo
# {'coord': {'lon': 73.0833, 'lat': -0.6}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 83.43, 'feels_like': 90.79, 'temp_min': 83.43, 'temp_max': 83.43, 'pressure': 1012, 'humidity': 75, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 12.8, 'deg': 48, 'gust': 13.94}, 'rain': {'1h': 0.86}, 'clouds': {'all': 100}, 'dt': 1642432808, 'sys': {'country': 'MV', 'sunrise': 1642381978, 'sunset': 1642425714}, 'timezone': 18000, 'id': 1282256, 'name': 'Hithadhoo', 'cod': 200}
# Processing Record 44 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=kijang
# {'coord': {'lon': 129.2139, 'lat': 35.2442}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 35.33, 'feels_like': 27.32, 'temp_min': 35.33, 'temp_max': 35.33, 'pressure': 1025, 'humidity': 52, 'sea_level': 1025, 'grnd_level': 1022}, 'visibility': 10000, 'wind': {'speed': 11.16, 'deg': 308, 'gust': 20.2}, 'clouds': {'all': 43}, 'dt': 1642432808, 'sys': {'type': 1, 'id': 8086, 'country': 'KR', 'sunrise': 1642458623, 'sunset': 1642494960}, 'timezone': 32400, 'id': 1842966, 'name': 'Gijang', 'cod': 200}
# Processing Record 45 of Set 1 | kijang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=bethel
# {'coord': {'lon': -73.414, 'lat': 41.3712}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 38.37, 'feels_like': 38.37, 'temp_min': 36.16, 'temp_max': 41.09, 'pressure': 983, 'humidity': 90}, 'visibility': 6437, 'wind': {'speed': 1.01, 'deg': 246, 'gust': 1.99}, 'rain': {'1h': 0.16}, 'clouds': {'all': 100}, 'dt': 1642432592, 'sys': {'type': 2, 'id': 2008903, 'country': 'US', 'sunrise': 1642421781, 'sunset': 1642456245}, 'timezone': -18000, 'id': 5282297, 'name': 'Bethel', 'cod': 200}
# Processing Record 46 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=arraial+do+cabo
# {'coord': {'lon': -42.0278, 'lat': -22.9661}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 87.66, 'feels_like': 95.32, 'temp_min': 87.66, 'temp_max': 87.76, 'pressure': 1013, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 60}, 'clouds': {'all': 0}, 'dt': 1642432808, 'sys': {'type': 1, 'id': 8326, 'country': 'BR', 'sunrise': 1642407429, 'sunset': 1642455528}, 'timezone': -10800, 'id': 3471451, 'name': 'Arraial do Cabo', 'cod': 200}
# Processing Record 47 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=yellowknife
# {'coord': {'lon': -114.3525, 'lat': 62.456}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': -16.08, 'feels_like': -28.68, 'temp_min': -16.08, 'temp_max': -16.08, 'pressure': 1020, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 350}, 'clouds': {'all': 100}, 'dt': 1642432686, 'sys': {'type': 1, 'id': 1007, 'country': 'CA', 'sunrise': 1642437723, 'sunset': 1642459959}, 'timezone': -25200, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# Processing Record 48 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=fortuna
# {'coord': {'lon': -124.1573, 'lat': 40.5982}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 38.32, 'feels_like': 38.32, 'temp_min': 38.32, 'temp_max': 39.54, 'pressure': 1018, 'humidity': 100}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 0}, 'dt': 1642432809, 'sys': {'type': 1, 'id': 4127, 'country': 'US', 'sunrise': 1642433830, 'sunset': 1642468559}, 'timezone': -28800, 'id': 5563839, 'name': 'Fortuna', 'cod': 200}
# Processing Record 49 of Set 1 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=geraldton
# {'coord': {'lon': 114.6, 'lat': -28.7667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 73.81, 'feels_like': 74.57, 'temp_min': 73.13, 'temp_max': 73.81, 'pressure': 1006, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 160}, 'clouds': {'all': 26}, 'dt': 1642432758, 'sys': {'type': 1, 'id': 9522, 'country': 'AU', 'sunrise': 1642369139, 'sunset': 1642418619}, 'timezone': 28800, 'id': 2070998, 'name': 'Geraldton', 'cod': 200}
# Processing Record 50 of Set 1 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=bredasdorp
# {'coord': {'lon': 20.0403, 'lat': -34.5322}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 76.32, 'feels_like': 76.51, 'temp_min': 76.32, 'temp_max': 83.28, 'pressure': 1013, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 16.11, 'deg': 170}, 'clouds': {'all': 13}, 'dt': 1642432810, 'sys': {'type': 1, 'id': 1966, 'country': 'ZA', 'sunrise': 1642391081, 'sunset': 1642442077}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# Processing Record 1 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=una
# {'coord': {'lon': 71.0333, 'lat': 20.8167}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 70.57, 'feels_like': 70.52, 'temp_min': 70.57, 'temp_max': 70.57, 'pressure': 1018, 'humidity': 68, 'sea_level': 1018, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 298, 'gust': 4.32}, 'clouds': {'all': 26}, 'dt': 1642432810, 'sys': {'country': 'IN', 'sunrise': 1642384500, 'sunset': 1642424176}, 'timezone': 19800, 'id': 1253783, 'name': 'Una', 'cod': 200}
# Processing Record 2 of Set 2 | una
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=kongolo
# {'coord': {'lon': 27, 'lat': -5.3833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 73.2, 'feels_like': 74.41, 'temp_min': 73.2, 'temp_max': 73.2, 'pressure': 1012, 'humidity': 89, 'sea_level': 1012, 'grnd_level': 949}, 'visibility': 10000, 'wind': {'speed': 3.78, 'deg': 5, 'gust': 5.77}, 'clouds': {'all': 100}, 'dt': 1642432810, 'sys': {'country': 'CD', 'sunrise': 1642392603, 'sunset': 1642437214}, 'timezone': 7200, 'id': 212360, 'name': 'Kongolo', 'cod': 200}
# Processing Record 3 of Set 2 | kongolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=grand+river+south+east
# {'cod': '404', 'message': 'city not found'}
# Processing Record 4 of Set 2 | grand river south east
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=ilulissat
# {'coord': {'lon': -51.1, 'lat': 69.2167}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': -16.87, 'feels_like': -29.47, 'temp_min': -16.87, 'temp_max': -16.87, 'pressure': 998, 'humidity': 95, 'sea_level': 998, 'grnd_level': 994}, 'visibility': 10000, 'wind': {'speed': 7.56, 'deg': 115, 'gust': 6.82}, 'clouds': {'all': 33}, 'dt': 1642432811, 'sys': {'country': 'GL', 'sunrise': 1642429431, 'sunset': 1642437883}, 'timezone': -10800, 'id': 3423146, 'name': 'Ilulissat', 'cod': 200}
# Processing Record 5 of Set 2 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=airai
# {'coord': {'lon': 125.4092, 'lat': -8.9266}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 61.61, 'feels_like': 61.79, 'temp_min': 61.61, 'temp_max': 61.61, 'pressure': 1011, 'humidity': 92, 'sea_level': 1011, 'grnd_level': 856}, 'visibility': 10000, 'wind': {'speed': 1.45, 'deg': 334, 'gust': 2.21}, 'rain': {'1h': 3.16}, 'clouds': {'all': 100}, 'dt': 1642432811, 'sys': {'country': 'TL', 'sunrise': 1642455075, 'sunset': 1642500334}, 'timezone': 32400, 'id': 1651810, 'name': 'Airai', 'cod': 200}
# Processing Record 6 of Set 2 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=port+hardy
# {'coord': {'lon': -127.4199, 'lat': 50.6996}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}, {'id': 520, 'main': 'Rain', 'description': 'light intensity shower rain', 'icon': '09n'}], 'base': 'stations', 'main': {'temp': 42.98, 'feels_like': 39.47, 'temp_min': 42.98, 'temp_max': 46.76, 'pressure': 1013, 'humidity': 93}, 'visibility': 9656, 'wind': {'speed': 5.75, 'deg': 150}, 'clouds': {'all': 100}, 'dt': 1642432522, 'sys': {'type': 1, 'id': 1011, 'country': 'CA', 'sunrise': 1642436593, 'sunset': 1642467363}, 'timezone': -28800, 'id': 6111862, 'name': 'Port Hardy', 'cod': 200}
# Processing Record 7 of Set 2 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.98, 'feels_like': 77.67, 'temp_min': 76.98, 'temp_max': 76.98, 'pressure': 1015, 'humidity': 70, 'sea_level': 1015, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 11.14, 'deg': 36, 'gust': 11.05}, 'clouds': {'all': 89}, 'dt': 1642432812, 'sys': {'country': 'PF', 'sunrise': 1642429730, 'sunset': 1642477850}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 8 of Set 2 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=avera
# {'coord': {'lon': -82.5271, 'lat': 33.194}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 39.52, 'feels_like': 30.58, 'temp_min': 38.53, 'temp_max': 41.72, 'pressure': 1012, 'humidity': 75, 'sea_level': 1012, 'grnd_level': 995}, 'visibility': 10000, 'wind': {'speed': 17.2, 'deg': 275, 'gust': 34.81}, 'clouds': {'all': 70}, 'dt': 1642432812, 'sys': {'type': 1, 'id': 2827, 'country': 'US', 'sunrise': 1642422775, 'sunset': 1642459627}, 'timezone': -18000, 'id': 4231997, 'name': 'Avera', 'cod': 200}
# Processing Record 9 of Set 2 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=villa+alemana
# {'coord': {'lon': -71.3733, 'lat': -33.0422}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 67.35, 'feels_like': 66.09, 'temp_min': 65.77, 'temp_max': 68.31, 'pressure': 1018, 'humidity': 49}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 250}, 'clouds': {'all': 20}, 'dt': 1642432813, 'sys': {'type': 1, 'id': 8520, 'country': 'CL', 'sunrise': 1642413244, 'sunset': 1642463803}, 'timezone': -10800, 'id': 3868192, 'name': 'Villa Alemana', 'cod': 200}
# Processing Record 10 of Set 2 | villa alemana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=montrose
# {'coord': {'lon': -108.2673, 'lat': 38.4166}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 12.61, 'feels_like': 7.05, 'temp_min': 4.41, 'temp_max': 26.37, 'pressure': 1027, 'humidity': 49, 'sea_level': 1027, 'grnd_level': 732}, 'visibility': 10000, 'wind': {'speed': 3.18, 'deg': 189, 'gust': 4.72}, 'clouds': {'all': 20}, 'dt': 1642432593, 'sys': {'type': 2, 'id': 2001307, 'country': 'US', 'sunrise': 1642429679, 'sunset': 1642465081}, 'timezone': -25200, 'id': 5431716, 'name': 'Montrose', 'cod': 200}
# Processing Record 11 of Set 2 | montrose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=cidreira
# {'coord': {'lon': -50.2056, 'lat': -30.1811}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 85.53, 'feels_like': 91.26, 'temp_min': 85.53, 'temp_max': 85.53, 'pressure': 1009, 'humidity': 63, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 7.16, 'deg': 39, 'gust': 9.08}, 'clouds': {'all': 95}, 'dt': 1642432813, 'sys': {'country': 'BR', 'sunrise': 1642408538, 'sunset': 1642458346}, 'timezone': -10800, 'id': 3466165, 'name': 'Cidreira', 'cod': 200}
# Processing Record 12 of Set 2 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=longyearbyen
# {'coord': {'lon': 15.6401, 'lat': 78.2186}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 6.64, 'feels_like': -5.96, 'temp_min': 6.64, 'temp_max': 6.64, 'pressure': 994, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 230}, 'clouds': {'all': 40}, 'dt': 1642432814, 'sys': {'type': 1, 'id': 1663, 'country': 'SJ', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 2729907, 'name': 'Longyearbyen', 'cod': 200}
# Processing Record 13 of Set 2 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=faanui
# {'coord': {'lon': -151.75, 'lat': -16.4833}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 76.86, 'feels_like': 78.48, 'temp_min': 76.86, 'temp_max': 76.86, 'pressure': 1008, 'humidity': 90, 'sea_level': 1008, 'grnd_level': 1008}, 'visibility': 4741, 'wind': {'speed': 13.42, 'deg': 15, 'gust': 14.27}, 'rain': {'1h': 2.64}, 'clouds': {'all': 100}, 'dt': 1642432814, 'sys': {'country': 'PF', 'sunrise': 1642434457, 'sunset': 1642481180}, 'timezone': -36000, 'id': 4034551, 'name': 'Faanui', 'cod': 200}
# Processing Record 14 of Set 2 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=sultanpur
# {'coord': {'lon': 82.0667, 'lat': 26.2667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 53.69, 'feels_like': 51.12, 'temp_min': 53.69, 'temp_max': 53.69, 'pressure': 1021, 'humidity': 50, 'sea_level': 1021, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 4.45, 'deg': 277, 'gust': 4.54}, 'clouds': {'all': 72}, 'dt': 1642432814, 'sys': {'country': 'IN', 'sunrise': 1642382440, 'sunset': 1642420938}, 'timezone': 19800, 'id': 1255491, 'name': 'Sultānpur', 'cod': 200}
# Processing Record 15 of Set 2 | sultanpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=shasta+lake
# {'coord': {'lon': -122.3708, 'lat': 40.6804}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 36.07, 'feels_like': 32.11, 'temp_min': 30.92, 'temp_max': 40.86, 'pressure': 1017, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 345, 'gust': 5.03}, 'clouds': {'all': 95}, 'dt': 1642432815, 'sys': {'type': 2, 'id': 2021301, 'country': 'US', 'sunrise': 1642433414, 'sunset': 1642468117}, 'timezone': -28800, 'id': 5571109, 'name': 'Lake Shasta', 'cod': 200}
# Processing Record 16 of Set 2 | shasta lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=volksrust
# {'coord': {'lon': 29.8818, 'lat': -27.3654}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 64.71, 'feels_like': 64.92, 'temp_min': 64.71, 'temp_max': 64.71, 'pressure': 1015, 'humidity': 86, 'sea_level': 1015, 'grnd_level': 838}, 'visibility': 10000, 'wind': {'speed': 5.19, 'deg': 115, 'gust': 8.9}, 'rain': {'1h': 0.59}, 'clouds': {'all': 68}, 'dt': 1642432815, 'sys': {'country': 'ZA', 'sunrise': 1642389655, 'sunset': 1642438778}, 'timezone': 7200, 'id': 943032, 'name': 'Volksrust', 'cod': 200}
# Processing Record 17 of Set 2 | volksrust
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=tsihombe
# {'cod': '404', 'message': 'city not found'}
# Processing Record 18 of Set 2 | tsihombe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=creston
# {'coord': {'lon': -94.3614, 'lat': 41.0586}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 21.45, 'feels_like': 13.91, 'temp_min': 17.04, 'temp_max': 27.68, 'pressure': 1015, 'humidity': 100}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 250}, 'clouds': {'all': 20}, 'dt': 1642432522, 'sys': {'type': 1, 'id': 3710, 'country': 'US', 'sunrise': 1642426756, 'sunset': 1642461328}, 'timezone': -21600, 'id': 4853078, 'name': 'Creston', 'cod': 200}
# Processing Record 19 of Set 2 | creston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=paracuru
# {'coord': {'lon': -39.0306, 'lat': -3.41}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 83.1, 'feels_like': 87.78, 'temp_min': 83.1, 'temp_max': 86.02, 'pressure': 1012, 'humidity': 67, 'sea_level': 1012, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 13.22, 'deg': 95, 'gust': 16.22}, 'rain': {'1h': 0.18}, 'clouds': {'all': 83}, 'dt': 1642432816, 'sys': {'type': 2, 'id': 2008290, 'country': 'BR', 'sunrise': 1642408636, 'sunset': 1642452883}, 'timezone': -10800, 'id': 3393115, 'name': 'Paracuru', 'cod': 200}
# Processing Record 20 of Set 2 | paracuru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=lata
# {'coord': {'lon': -8.3327, 'lat': 40.1629}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 59.59, 'feels_like': 57.18, 'temp_min': 57.04, 'temp_max': 62.92, 'pressure': 1029, 'humidity': 41, 'sea_level': 1029, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 5.44, 'deg': 39, 'gust': 7.85}, 'clouds': {'all': 16}, 'dt': 1642432816, 'sys': {'type': 2, 'id': 2001739, 'country': 'PT', 'sunrise': 1642405971, 'sunset': 1642440809}, 'timezone': 0, 'id': 2738381, 'name': 'Lata', 'cod': 200}
# Processing Record 21 of Set 2 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=sao+joao+da+barra
# ...
# Processing Record 23 of Set 15 | mizdah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=west+wendover
# {'coord': {'lon': -114.0733, 'lat': 40.7391}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 16.81, 'feels_like': 16.81, 'temp_min': 16.81, 'temp_max': 16.81, 'pressure': 1024, 'humidity': 93, 'sea_level': 1024, 'grnd_level': 866}, 'visibility': 10000, 'wind': {'speed': 1.39, 'deg': 42, 'gust': 1.77}, 'clouds': {'all': 94}, 'dt': 1642432811, 'sys': {'type': 1, 'id': 3994, 'country': 'US', 'sunrise': 1642431433, 'sunset': 1642466114}, 'timezone': -25200, 'id': 5710035, 'name': 'West Wendover', 'cod': 200}
# Processing Record 24 of Set 15 | west wendover
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=parrita
# {'coord': {'lon': -84.3225, 'lat': 9.5201}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 86.05, 'feels_like': 88.86, 'temp_min': 84.81, 'temp_max': 87.57, 'pressure': 1014, 'humidity': 53, 'sea_level': 1014, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 1.59, 'deg': 175, 'gust': 2.51}, 'clouds': {'all': 4}, 'dt': 1642433049, 'sys': {'type': 1, 'id': 7205, 'country': 'CR', 'sunrise': 1642420688, 'sunset': 1642462576}, 'timezone': -21600, 'id': 3622537, 'name': 'Parrita', 'cod': 200}
# Processing Record 25 of Set 15 | parrita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=cabra
# {'coord': {'lon': -4.4421, 'lat': 37.4725}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 62.37, 'feels_like': 60.33, 'temp_min': 48.67, 'temp_max': 63.18, 'pressure': 1027, 'humidity': 43}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 30, 'gust': 4}, 'clouds': {'all': 0}, 'dt': 1642433050, 'sys': {'type': 2, 'id': 2008401, 'country': 'ES', 'sunrise': 1642404628, 'sunset': 1642440284}, 'timezone': 3600, 'id': 2520645, 'name': 'Cabra', 'cod': 200}
# Processing Record 26 of Set 15 | cabra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=nuristan
# {'coord': {'lon': 70.8333, 'lat': 35.3}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 15.51, 'feels_like': 15.51, 'temp_min': 15.51, 'temp_max': 15.51, 'pressure': 1025, 'humidity': 97, 'sea_level': 1025, 'grnd_level': 663}, 'visibility': 332, 'wind': {'speed': 2.13, 'deg': 350, 'gust': 2.57}, 'snow': {'1h': 0.13}, 'clouds': {'all': 100}, 'dt': 1642433050, 'sys': {'country': 'AF', 'sunrise': 1642386258, 'sunset': 1642422514}, 'timezone': 16200, 'id': 1444363, 'name': 'Nuristan', 'cod': 200}
# Processing Record 27 of Set 15 | nuristan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=adrar
# {'coord': {'lon': -10.0711, 'lat': 20.5022}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 74.28, 'feels_like': 71.89, 'temp_min': 74.28, 'temp_max': 74.28, 'pressure': 1019, 'humidity': 10, 'sea_level': 1019, 'grnd_level': 975}, 'visibility': 10000, 'wind': {'speed': 15.32, 'deg': 83, 'gust': 16.44}, 'clouds': {'all': 22}, 'dt': 1642433051, 'sys': {'country': 'MR', 'sunrise': 1642403932, 'sunset': 1642443683}, 'timezone': 0, 'id': 2381972, 'name': 'Adrar', 'cod': 200}
# Processing Record 28 of Set 15 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=ismailia
# {'coord': {'lon': 32.2723, 'lat': 30.6043}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 55.15, 'feels_like': 52.38, 'temp_min': 55.15, 'temp_max': 55.15, 'pressure': 1022, 'humidity': 43, 'sea_level': 1022, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 9.75, 'deg': 38, 'gust': 13.8}, 'clouds': {'all': 78}, 'dt': 1642432998, 'sys': {'country': 'EG', 'sunrise': 1642394900, 'sunset': 1642432385}, 'timezone': 7200, 'id': 361055, 'name': 'Ismailia', 'cod': 200}
# Processing Record 29 of Set 15 | ismailia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=san+ignacio
# {'coord': {'lon': -89.0714, 'lat': 17.1561}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 66.34, 'feels_like': 66.81, 'temp_min': 66.34, 'temp_max': 66.34, 'pressure': 1023, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 75}, 'dt': 1642433051, 'sys': {'type': 1, 'id': 7082, 'country': 'BZ', 'sunrise': 1642422556, 'sunset': 1642462988}, 'timezone': -21600, 'id': 3581194, 'name': 'San Ignacio', 'cod': 200}
# Processing Record 30 of Set 15 | san ignacio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=okhotsk
# {'coord': {'lon': 143.3, 'lat': 59.3833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -0.4, 'feels_like': -13, 'temp_min': -0.4, 'temp_max': -0.4, 'pressure': 1027, 'humidity': 77, 'sea_level': 1027, 'grnd_level': 1026}, 'visibility': 10000, 'wind': {'speed': 10.31, 'deg': 350, 'gust': 17.72}, 'clouds': {'all': 100}, 'dt': 1642433052, 'sys': {'country': 'RU', 'sunrise': 1642460758, 'sunset': 1642486061}, 'timezone': 36000, 'id': 2122605, 'name': 'Okhotsk', 'cod': 200}
# Processing Record 31 of Set 15 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=majene
# {'coord': {'lon': 118.9707, 'lat': -3.5403}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 78.42, 'feels_like': 79.83, 'temp_min': 78.42, 'temp_max': 78.42, 'pressure': 1010, 'humidity': 82, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 7.09, 'deg': 339, 'gust': 9.06}, 'clouds': {'all': 100}, 'dt': 1642433052, 'sys': {'country': 'ID', 'sunrise': 1642370693, 'sunset': 1642414967}, 'timezone': 28800, 'id': 1636806, 'name': 'Majene', 'cod': 200}
# Processing Record 32 of Set 15 | majene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=puyang
# {'coord': {'lon': 119.8861, 'lat': 29.4603}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 45.84, 'feels_like': 45.84, 'temp_min': 45.84, 'temp_max': 45.84, 'pressure': 1029, 'humidity': 93, 'sea_level': 1029, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 2.51, 'deg': 43, 'gust': 2.53}, 'rain': {'1h': 0.11}, 'clouds': {'all': 100}, 'dt': 1642433052, 'sys': {'country': 'CN', 'sunrise': 1642373736, 'sunset': 1642411484}, 'timezone': 28800, 'id': 1798425, 'name': 'Puyang', 'cod': 200}
# Processing Record 33 of Set 15 | puyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=bonavista
# {'coord': {'lon': -53.1147, 'lat': 48.6499}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 24.8, 'feels_like': 13.68, 'temp_min': 24.8, 'temp_max': 28.11, 'pressure': 1025, 'humidity': 64, 'sea_level': 1025, 'grnd_level': 1025}, 'visibility': 10000, 'wind': {'speed': 12.1, 'deg': 260, 'gust': 13.96}, 'clouds': {'all': 6}, 'dt': 1642433053, 'sys': {'type': 1, 'id': 719, 'country': 'CA', 'sunrise': 1642418295, 'sunset': 1642449985}, 'timezone': -12600, 'id': 5905393, 'name': 'Bonavista', 'cod': 200}
# Processing Record 34 of Set 15 | bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=filadelfia
# {'coord': {'lon': -75.1638, 'lat': 39.9523}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 35.2, 'feels_like': 28.2, 'temp_min': 32.76, 'temp_max': 37.42, 'pressure': 986, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 8.99, 'deg': 250, 'gust': 23}, 'clouds': {'all': 100}, 'dt': 1642432888, 'sys': {'type': 2, 'id': 2037403, 'country': 'US', 'sunrise': 1642421973, 'sunset': 1642456894}, 'timezone': -18000, 'id': 4560349, 'name': 'Philadelphia', 'cod': 200}
# Processing Record 35 of Set 15 | filadelfia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=soyo
# {'coord': {'lon': 12.3689, 'lat': -6.1349}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 86.05, 'feels_like': 93.92, 'temp_min': 86.05, 'temp_max': 86.05, 'pressure': 1012, 'humidity': 67, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 8.99, 'deg': 253, 'gust': 8.41}, 'clouds': {'all': 84}, 'dt': 1642433053, 'sys': {'type': 1, 'id': 2165, 'country': 'AO', 'sunrise': 1642396046, 'sunset': 1642440796}, 'timezone': 3600, 'id': 2236967, 'name': 'Soyo', 'cod': 200}
# Processing Record 36 of Set 15 | soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=aleksandrovskoye
# {'coord': {'lon': 43.0008, 'lat': 44.7142}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 26.74, 'feels_like': 21.97, 'temp_min': 24.15, 'temp_max': 26.74, 'pressure': 1019, 'humidity': 82, 'sea_level': 1019, 'grnd_level': 981}, 'visibility': 10000, 'wind': {'speed': 4.03, 'deg': 171, 'gust': 5.82}, 'clouds': {'all': 7}, 'dt': 1642433054, 'sys': {'type': 1, 'id': 8966, 'country': 'RU', 'sunrise': 1642394440, 'sunset': 1642427695}, 'timezone': 10800, 'id': 582993, 'name': 'Aleksandrovskoye', 'cod': 200}
# Processing Record 37 of Set 15 | aleksandrovskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=mumford
# {'coord': {'lon': -0.759, 'lat': 5.2618}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 83.52, 'feels_like': 88.57, 'temp_min': 83.52, 'temp_max': 83.52, 'pressure': 1011, 'humidity': 67, 'sea_level': 1011, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 13.04, 'deg': 199, 'gust': 11.52}, 'clouds': {'all': 69}, 'dt': 1642433054, 'sys': {'country': 'GH', 'sunrise': 1642400238, 'sunset': 1642442906}, 'timezone': 0, 'id': 2297810, 'name': 'Mumford', 'cod': 200}
# Processing Record 38 of Set 15 | mumford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=makat
# {'coord': {'lon': 53.3463, 'lat': 47.6469}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 26.38, 'feels_like': 17.06, 'temp_min': 26.38, 'temp_max': 26.38, 'pressure': 1021, 'humidity': 85, 'sea_level': 1021, 'grnd_level': 1024}, 'visibility': 10000, 'wind': {'speed': 9.51, 'deg': 235, 'gust': 14.92}, 'clouds': {'all': 100}, 'dt': 1642433055, 'sys': {'country': 'KZ', 'sunrise': 1642392541, 'sunset': 1642424626}, 'timezone': 18000, 'id': 608872, 'name': 'Makat', 'cod': 200}
# Processing Record 39 of Set 15 | makat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=tigil
# {'coord': {'lon': 158.6667, 'lat': 57.8}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': -8.64, 'feels_like': -20.97, 'temp_min': -8.64, 'temp_max': -8.64, 'pressure': 1018, 'humidity': 87, 'sea_level': 1018, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 5.19, 'deg': 41, 'gust': 4.94}, 'clouds': {'all': 3}, 'dt': 1642433055, 'sys': {'country': 'RU', 'sunrise': 1642456446, 'sunset': 1642482996}, 'timezone': 43200, 'id': 2120612, 'name': "Tigil'", 'cod': 200}
# Processing Record 40 of Set 15 | tigil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=severnyy
# {'coord': {'lon': 36.5532, 'lat': 50.677}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 30.24, 'feels_like': 19.96, 'temp_min': 30.24, 'temp_max': 30.24, 'pressure': 996, 'humidity': 86}, 'visibility': 4600, 'wind': {'speed': 13.42, 'deg': 220}, 'clouds': {'all': 100}, 'dt': 1642433055, 'sys': {'type': 1, 'id': 9030, 'country': 'RU', 'sunrise': 1642397258, 'sunset': 1642427972}, 'timezone': 10800, 'id': 496358, 'name': 'Severnyy', 'cod': 200}
# Processing Record 41 of Set 15 | severnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=asyut
# {'coord': {'lon': 31.1837, 'lat': 27.181}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 57.76, 'feels_like': 55.02, 'temp_min': 57.76, 'temp_max': 57.76, 'pressure': 1020, 'humidity': 38, 'sea_level': 1020, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 11.48, 'deg': 346, 'gust': 15.48}, 'clouds': {'all': 72}, 'dt': 1642433056, 'sys': {'country': 'EG', 'sunrise': 1642394755, 'sunset': 1642433053}, 'timezone': 7200, 'id': 359783, 'name': 'Assiut', 'cod': 200}
# Processing Record 42 of Set 15 | asyut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=merauke
# {'coord': {'lon': 140.3333, 'lat': -8.4667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 78.82, 'feels_like': 78.82, 'temp_min': 78.82, 'temp_max': 78.82, 'pressure': 1007, 'humidity': 85, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 7694, 'wind': {'speed': 5.84, 'deg': 310, 'gust': 7.47}, 'clouds': {'all': 96}, 'dt': 1642433056, 'sys': {'country': 'ID', 'sunrise': 1642451535, 'sunset': 1642496709}, 'timezone': 32400, 'id': 2082539, 'name': 'Merauke', 'cod': 200}
# Processing Record 43 of Set 15 | merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=vicksburg
# {'coord': {'lon': -90.8779, 'lat': 32.3526}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 42.22, 'feels_like': 36.25, 'temp_min': 39.43, 'temp_max': 44.28, 'pressure': 1021, 'humidity': 68}, 'visibility': 6437, 'wind': {'speed': 10.36, 'deg': 330}, 'clouds': {'all': 0}, 'dt': 1642432901, 'sys': {'type': 1, 'id': 6181, 'country': 'US', 'sunrise': 1642424670, 'sunset': 1642461741}, 'timezone': -21600, 'id': 4449620, 'name': 'Vicksburg', 'cod': 200}
# Processing Record 44 of Set 15 | vicksburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=anar+darreh
# {'cod': '404', 'message': 'city not found'}
# Processing Record 45 of Set 15 | anar darreh
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=24d59aebdfe6e5cf0723f04f760d6115&q=katha
# {'cod': '404', 'message': 'city not found'}
# Processing Record 46 of Set 15 | katha
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 695

# %%
# Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0       Jamestown  42.0970  -79.2353     27.72                snow        70
# 1       Mogadishu   2.0371   45.3438     79.23    scattered clouds        76
# 2        Hermanus -34.4187   19.2345     83.80          few clouds        66
# 3   Mar Del Plata -38.0023  -57.5575     69.01       moderate rain        55
# 4        Udachnyy  66.4167  112.4000     -7.83     overcast clouds        97
# 5    Saint George  37.1041 -113.5841     32.47           clear sky        80
# 6       Esperance -33.8667  121.9000     61.09           clear sky        74
# 7        Khatanga  71.9667  102.5000    -18.09           clear sky        94
# 8        Thompson  55.7435  -97.8558    -27.24          few clouds        75
# 9  Ribeira Grande  38.5167  -28.7000     59.40    scattered clouds        72
#
#    Cloudiness  Wind Speed Country
# 0         100        8.99      US
# 1          32       21.00      SO
# 2          11       13.60      ZA
# 3         100       18.99      AR
# 4         100       12.93      RU
# 5           0        0.00      US
# 6           4       17.40      AU
# 7          10        7.87      RU
# 8          20        5.75      CA
# 9          40        6.91      PT

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Jamestown      US  42.0970  -79.2353     27.72        70         100
# 1       Mogadishu      SO   2.0371   45.3438     79.23        76          32
# 2        Hermanus      ZA -34.4187   19.2345     83.80        66          11
# 3   Mar Del Plata      AR -38.0023  -57.5575     69.01        55         100
# 4        Udachnyy      RU  66.4167  112.4000     -7.83        97         100
# 5    Saint George      US  37.1041 -113.5841     32.47        80           0
# 6       Esperance      AU -33.8667  121.9000     61.09        74           4
# 7        Khatanga      RU  71.9667  102.5000    -18.09        94          10
# 8        Thompson      CA  55.7435  -97.8558    -27.24        75          20
# 9  Ribeira Grande      PT  38.5167  -28.7000     59.40        72          40
#
#    Wind Speed Current Description
# 0        8.99                snow
# 1       21.00    scattered clouds
# 2       13.60          few clouds
# 3       18.99       moderate rain
# 4       12.93     overcast clouds
# 5        0.00           clear sky
# 6       17.40           clear sky
# 7        7.87           clear sky
# 8        5.75          few clouds
# 9        6.91    scattered clouds

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
